# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshini382/Stroke_prediction/blob/main/STROKE_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Libraries and dataset:**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

# Load the dataset
data = pd.read_csv('healthcare-dataset-stroke-data.csv')

# Display the first few rows of the dataset
print(data.head())
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # **Data Analysis and Visualization**

# %% [markdown]
# # **Gender and Stroke Distribution**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', hue='stroke', data=data)
plt.title('Gender and Stroke Distribution')
plt.show()

# %% [markdown]
# # **Age Distribution and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='age', hue='stroke', multiple='stack', kde=True)
plt.title('Age Distribution and Stroke')
plt.show()

# %% [markdown]
# # Hypertension and **Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='hypertension', hue='stroke', data=data)
plt.title('Hypertension and Stroke')
plt.show()

# %% [markdown]
# # **Heart Disease and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='heart_disease', hue='stroke', data=data)
plt.title('Heart Disease and Stroke')
plt.show()

# %% [markdown]
# # **Marital Status and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='ever_married', hue='stroke', data=data)
plt.title('Marital Status and Stroke')
plt.show()

# %% [markdown]
# # **Work Type Distribution and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='work_type', hue='stroke', data=data)
plt.title('Work Type and Stroke')
plt.show()

# %% [markdown]
# # **Residence Type and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Residence_type', hue='stroke', data=data)
plt.title('Residence Type and Stroke')
plt.show()

# %% [markdown]
# # **Average Glucose Level Distribution and Stroke** **bold text**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='avg_glucose_level', hue='stroke', multiple='stack', kde=True)
plt.title('Average Glucose Level and Stroke')
plt.show()

# %% [markdown]
# # **Smoking Status Distribution and Stroke**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='smoking_status', hue='stroke', data=data)
plt.title('Smoking Status and Stroke')
plt.show()

# %% [markdown]
# # ***Regression Analysis***

# %% [markdown]
# # Data Preprocessing for *Regression*

# %%
# Handling missing values
data.dropna(inplace=True)

# Encoding categorical variables
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])
data['ever_married'] = le.fit_transform(data['ever_married'])
data['work_type'] = le.fit_transform(data['work_type'])
data['Residence_type'] = le.fit_transform(data['Residence_type'])
data['smoking_status'] = le.fit_transform(data['smoking_status'])

# Splitting the data into features and target variable
X = data.drop(['stroke', 'id'], axis=1)
y = data['stroke']

# %% [markdown]
# # **Linear Regression**
# Predicting avg_glucose_level using other features:

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, mean_squared_error, r2_score

# Assuming you have already split and fitted the linear regression model as described
# X_train_glucose, X_test_glucose, y_train_glucose, y_test_glucose

# Predictions
y_pred_glucose = linear_model.predict(X_test_glucose)

# Define a threshold for classification (example: median of y_train_glucose)
threshold = np.median(y_train_glucose)
y_pred_class = np.where(y_pred_glucose > threshold, 1, 0)
y_test_class = np.where(y_test_glucose > threshold, 1, 0)

# Compute classification metrics
precision = precision_score(y_test_class, y_pred_class)
recall = recall_score(y_test_class, y_pred_class)
f1 = f1_score(y_test_class, y_pred_class)

# Also compute regression metrics (optional)
mse = mean_squared_error(y_test_glucose, y_pred_glucose)
r2 = r2_score(y_test_glucose, y_pred_glucose)

print("Metrics for Linear Regression (as classification):")
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nRegression Metrics (optional):")
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Metrics for Linear Regression (as classification):
# Precision: 0.5317965023847376
# Recall: 0.8733681462140992
# F1 Score: 0.6610671936758893
#
# Regression Metrics (optional):
# Mean Squared Error: 1851.83957590756
# R^2 Score: 0.07455791334432937

# %% [markdown]
# # ***Logistic Regression***
# Predicting stroke:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Fitting the model
logistic_model = LogisticRegression(max_iter=1000)
logistic_model.fit(X_train, y_train)

# Predictions
y_pred = logistic_model.predict(X_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Logistic Regression for stroke prediction:")
print("Accuracy Score:", accuracy)
print("Precision Score:", precision)
print("Recall Score:", recall)
print("F1 Score:", f1)
# Out:
# Logistic Regression for stroke prediction:
# Accuracy Score: 0.9511201629327902
# Precision Score: 0.0
# Recall Score: 0.0
# F1 Score: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # ***Multiple Linear Regression***
# Predicting bmi using other features:

# %%
# Finding the median of bmi
bmi_median = np.median(data['bmi'])

# Binarizing bmi based on median
data['bmi_class'] = np.where(data['bmi'] > bmi_median, 1, 0)
# Splitting the data into features (X) and binary target (y_bmi_class)
X_bmi = X.drop('bmi', axis=1)
y_bmi_class = data['bmi_class']

X_train_bmi, X_test_bmi, y_train_bmi, y_test_bmi = train_test_split(X_bmi, y_bmi_class, test_size=0.3, random_state=42)
# Fitting the model
multiple_linear_model = LinearRegression()
multiple_linear_model.fit(X_train_bmi, y_train_bmi)

# Predictions (convert to binary predictions)
y_pred_bmi = np.where(multiple_linear_model.predict(X_test_bmi) > 0.5, 1, 0)

# Evaluation metrics for classification
precision = precision_score(y_test_bmi, y_pred_bmi)
recall = recall_score(y_test_bmi, y_pred_bmi)
f1 = f1_score(y_test_bmi, y_pred_bmi)

print("Multiple Linear Regression for bmi (Binary Classification):")
print("Precision Score:", precision)
print("Recall Score:", recall)
print("F1 Score:", f1)
# Out:
# Multiple Linear Regression for bmi (Binary Classification):
# Precision Score: 0.622969837587007
# Recall Score: 0.7336065573770492
# F1 Score: 0.6737766624843162

# %% [markdown]
# # ***ACCURACY SCORE VISUALIZATION***

# %%
import matplotlib.pyplot as plt

# Example accuracy scores (replace with your actual scores)
accuracy_linear = 0.78
accuracy_logistic = 0.85
accuracy_multiple_linear = 0.72

# Plotting the accuracy scores
models = ['Linear Regression', 'Logistic Regression', 'Multiple Linear Regression']
accuracy_scores = [accuracy_linear, accuracy_logistic, accuracy_multiple_linear]

plt.figure(figsize=(10, 6))
plt.bar(models, accuracy_scores, color=['blue', 'green', 'orange'])
plt.ylim(0.6, 1.0)  # Setting y-axis limit for better visualization
plt.title('Accuracy Scores of Regression Models')
plt.xlabel('Models')
plt.ylabel('Accuracy Score')
plt.show()

# %% [markdown]
# # **HAVING STROKE OR NOT**

# %%
for index, row in data.iterrows():
    person_id = index + 1  # Assuming person 1 corresponds to index 0
    has_stroke = "Yes" if row['stroke'] == 1 else "No"
    print(f"Person {person_id}: {has_stroke}")
# Out:
# Person 1: Yes
# Person 3: Yes
# Person 4: Yes
# Person 5: Yes
# Person 6: Yes
# Person 7: Yes
# Person 8: Yes
# Person 10: Yes
# Person 11: Yes
# Person 12: Yes
# Person 13: Yes
# Person 15: Yes
# Person 16: Yes
# Person 17: Yes
# Person 18: Yes
# Person 19: Yes
# Person 21: Yes
# Person 22: Yes
# Person 23: Yes
# Person 24: Yes
# Person 25: Yes
# Person 26: Yes
# Person 27: Yes
# Person 29: Yes
# Person 31: Yes
# Person 32: Yes
# Person 33: Yes
# Person 34: Yes
# Person 35: Yes
# Person 36: Yes
# Person 37: Yes
# Person 38: Yes
# Person 39: Yes
# Person 40: Yes
# Person 41: Yes
# Person 42: Yes
# Person 43: Yes
# Person 45: Yes
# Person 46: Yes
# Person 48: Yes
# Person 49: Yes
# Person 50: Yes
# Person 53: Yes
# Person 54: Yes
# Person 56: Yes
# Person 57: Yes
# Person 59: Yes
# Person 60: Yes
# Person 61: Yes
# Person 62: Yes
# Person 63: Yes
# Person 64: Yes
# Person 66: Yes
# Person 67: Yes
# Person 68: Yes
# Person 69: Yes
# Person 70: Yes
# Person 72: Yes
# Person 73: Yes
# ...

# %% [markdown]
# # ***POSSIBILITES OF OCUURCING STROKE***

# %%
# Calculate stroke occurrence proportions by category
gender_stroke = data.groupby('gender')['stroke'].mean()
hypertension_stroke = data.groupby('hypertension')['stroke'].mean()
heart_disease_stroke = data.groupby('heart_disease')['stroke'].mean()
ever_married_stroke = data.groupby('ever_married')['stroke'].mean()
work_type_stroke = data.groupby('work_type')['stroke'].mean()
residence_type_stroke = data.groupby('Residence_type')['stroke'].mean()
smoking_status_stroke = data.groupby('smoking_status')['stroke'].mean()

# Display stroke occurrence proportions
print("Stroke Occurrence Proportions:")
print("Gender:")
print(gender_stroke)
print("\nHypertension:")
print(hypertension_stroke)
print("\nHeart Disease:")
print(heart_disease_stroke)
print("\nEver Married:")
print(ever_married_stroke)
print("\nWork Type:")
print(work_type_stroke)
print("\nResidence Type:")
print(residence_type_stroke)
print("\nSmoking Status:")
print(smoking_status_stroke)
# Out:
# Stroke Occurrence Proportions:
# Gender:
# gender
# 0    0.041422
# 1    0.044257
# 2    0.000000
# Name: stroke, dtype: float64
#
# Hypertension:
# hypertension
# 0    0.033423
# 1    0.133038
# Name: stroke, dtype: float64
#
# Heart Disease:
# heart_disease
# 0    0.036219
# 1    0.164609
# Name: stroke, dtype: float64
#
# Ever Married:
# ever_married
# 0    0.013490
# 1    0.058052
# Name: stroke, dtype: float64
#
# Work Type:
# work_type
# 0    0.044444
# 1    0.000000
# 2    0.045180
# 3    0.068387
# 4    0.001490
# Name: stroke, dtype: float64
#
# Residence Type:
# Residence_type
# 0    0.041339
# 1    0.043775
# Name: stroke, dtype: float64
#
# Smoking Status:
# smoking_status
# 0    0.019555
# 1    0.068100
# 2    0.045356
# 3    0.052917
# Name: stroke, dtype: float64

# %% [markdown]
# # **VISULAIZATION**

# %%
# Drop non-numeric columns that cannot be used for correlation calculation
data_numeric = data.drop(['id', 'gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status'], axis=1)

# Calculate the correlation coefficients between numeric features and the target variable
correlations = data_numeric.corr()['stroke'].abs().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x=correlations.values, y=correlations.index, orient='h', palette='Blues_r')
plt.xlabel('Correlation with Stroke')
plt.ylabel('Features')
plt.title('Feature Importance Based on Correlation with Stroke')
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-27-d497895537ab>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlations.values, y=correlations.index, orient='h', palette='Blues_r')

# %%
if hasattr(logistic_model, 'coef_'):
    feature_importance = logistic_model.coef_[0]
    feature_names = X.columns
    plt.figure(figsize=(10, 8))
    sns.barplot(x=feature_importance, y=feature_names, orient='h', palette='Blues_r')
    plt.xlabel('Feature Importance')
    plt.ylabel('Features')
    plt.title('Feature Importance Plot')
    plt.tight_layout()

plt.show()
# Out:
# <ipython-input-28-e06495caebee>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importance, y=feature_names, orient='h', palette='Blues_r')
